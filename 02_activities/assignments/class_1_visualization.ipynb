# %%
# This is the code file for class 1 in data visualization 
# I hope I have set this up correctly lol
# python-graph-gallery.com/all-charts is a great recourse for picking code for a nice visualization

# %%
# load libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# Make our first figure wee

# set seed
np.random.seed(613)

# set x and y data
x = np.arange(50)
y = np.random.randint(0, 100, 50)

# Initiate figure and axes
fig,ax = plt.subplots(figsize = (5,3))
# want axes object to be a scatter plot
ax.scatter(x,y)

# %%
# Generated first graph, now let's modify it
fig, ax = plt.subplots(figsize = (5,3))
# bar = vertical bars, barh = horizontal bars
ax.barh(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize = (5,3))
# For line pllots, use simply "plot"
ax.plot(x,y)

# %%
# Can we modify code to produce a histogram?
fig, ax = plt.subplots(figsize = (5,3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize = (5,3))
# Define the axis before you define its parts
ax.plot(x,y)
# Now the parts
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')

# Here tight_layout doesn't do anything
# it's meant for subplots
fig.tight_layout()

# %%
# Modifying labels and titles
# Let's initiate our fonts

font1 = {'family':'sans-serif','color':'blue',
         'size':20}
font2 = {'family':'monospace','color':'green',
         'size':14}

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

ax.set_title('Total growth over time lets make this a really long title', fontdict = font1,loc='left')
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
#fig.tight_layout()
# Out:
# Text(0.5, 0, 'Years since start')

# %%
# Modifying our data points

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x, y,
           marker = '*',
           color = 'indigo')

# %%
fig, ax = plt.subplots(figsize = (5,3))

ax.plot(x,y,
        marker = '*',
        color = 'indigo', # can also use hex codes
        linestyle = '--',
        linewidth = 2)

# %%
fig, ax = plt.subplots(figsize = (5,3))

ax.plot(x,y,
        marker = '*',
        color = '#7425b9', # can also use hex codes
        linestyle = '--',
        linewidth = 2)

# %%
fig, ax = plt.subplots(figsize = (5,3))

ax.plot(x,y,
        marker = '*',
        markersize = 12,
        color = '#7425b9',
        linestyle = '--',
        linewidth = 2,
        markeredgecolor = '#fa9359',
        markerfacecolor = '#000000')

# Adding gridlines
ax.grid(axis = 'y', 
        color = 'blue',
        linewidth = 2,
        linestyle = '-.')

# %%
# Class activity
# I'm copying the mirror histogram

# libraries
import numpy as np
from numpy import linspace
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# dataframe
df = pd.DataFrame({
'var1': np.random.normal(size=1000),
'var2': np.random.normal(loc=2, size=1000) * -1
})

# Fig size
plt.rcParams["figure.figsize"]=12,8

# plot density chart for var1
sns.kdeplot(data=df, x="var1",  fill=True, alpha=1)

# plot density chart for var2
kde = gaussian_kde(df.var2)
x_range = linspace(min(df.var2), max(df.var2), len(df.var2))

# multiply by -1 to reverse axis (mirror plot)
sns.lineplot(x=x_range*-1, y=kde(x_range) * -1, color='orange') 
plt.fill_between(x_range*-1, kde(x_range) * -1, color='orange')

# add axis names        
plt.xlabel("value of x")
plt.axhline(y=0, linestyle='-',linewidth=1, color='black')



# show the graph
plt.show()

# %%
# Very nice. Though what happened to my bars...

# Aesthetic
    # Certainly pretty...very clean
# Substantive 
    # Depending on the data this could paint quite a picture
# Perceptual
    # There's definitely room for misunderstanding depending on the units of the data and how its pared
