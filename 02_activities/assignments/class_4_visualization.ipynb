# %%
# load libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# sample data
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0,75,50)
x2 = np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y2 = np.array([110,180,240,99,220])

# %%
# Want subplots, so defining two ax objects
fig, (ax1, ax2) = plt.subplots(ncols=2,
                               nrows=1,
                               figsize=(7,3))
# ax1 will be scatter plot using x1, y1
ax1.scatter(x1,y1)
# ax2 will be bar graph using x2, y2
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
# ACTIVITY: Add some random modification to the previous plot
plt.style.use("ggplot")
fig, (ax1, ax2) = plt.subplots(ncols=2,
                               nrows=1,
                               figsize=(7,3))

font = {'family':'sans-serif','color':'blue',
         'size':36}
ax1.scatter(x1,y1)
ax1.set_xlabel('SCATTER',fontdict=font)
ax2.bar(x2,y2)
ax2.set_xlabel('BAR',fontdict=font)
# Out:
# Text(0.5, 0, 'BAR')

# %%
# Using subplot_mosaic
plt.style.use("default")
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                    figsize=(7,4))
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

# %%
# Now let's add large x-labels and see what happens

fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                    figsize=(7,4))
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

# NOW ADDING:
someaxes["ax1"].set_xlabel("A Big Label",fontsize=18)
someaxes["ax2"].set_xlabel("Another Label",fontsize=18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious",fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
# boo...so much got cut....
# What do we do about that?
# Fix this with LAYOUTS
# 2 main kinds:  tight_layout() or contrained_layout()
# Contrained is tight but will also adjust legends, colorbars etc.

fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']],
                                    figsize=(7,4),
                                    layout = "constrained") # NOW ADDED THISS
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel("A Big Label",fontsize=18)
someaxes["ax2"].set_xlabel("Another Label",fontsize=18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious",fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
# Multiple viz on one axes object

x = np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

# Define figure and axes (just one this time)
fig, ax = plt.subplots(figsize=(7,3))

# Now call both bar and plot elements to SAME axes, ax:
ax.bar(x, y1,
       color = "indigo")
ax.plot(x,y2,
        color="red")

# %%
# Adding in errorbars

y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red')

ax.errorbar(x,y2,
            yerr = y2_sd,
            fmt = "none")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Now let's customize the appearance of the errorbars

y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2,color='red')

ax.errorbar(x,y2,
            yerr = y2_sd,
            fmt = "none",
            ecolor="indigo",
            elinewidth = 4,
            capsize = 6,
            capthick = 4,
            errorevery = 2 # this one we add if we don't want to see error bars for EVERY point
            )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# load libraries

from PIL import Image
from io import BytesIO

# %%
# Get image from internet
response = requests.get('https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png')
image_file = BytesIO(response.content)
image = Image.open(image_file)

# %%
# Now let's add the image to a plot

# Let's make a basic line plot (reusing our data)
fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x, y2, color = "red")

# NOW we are OVERLAYING a new axis (ax_image) on our figure to act as a container for our image
ax_image = fig.add_axes([0.1, # x coordinate(ON FIGURE, NOT AXES)
                         0.11, # y coordinate (ON FIGURE, NOT AXES)
                         0.15, # image width
                         0.35]) # image height

# Now we want to add our image and then get rid of that axis border
ax_image.imshow(image)
ax_image.axis('off')
# Out:
# (-0.5, 219.5, 425.5, -0.5)

# %%
# SAVING A VIZ
# Keeping this commented out because I don't want to save anything right now

# FIRST DEFINE PLACE/PATH TO SAVE
# path = 'C:/Users/...' # Can be a full or relative path
# filename = '/fig1a.png

# plt.savefig....boo the slize changed....well anyways this was just a resource and it's there if I need it
